# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import datetime as dt


from tensorflow.keras.layers import Dense, Dropout
from keras.layers import GRU
from keras.models import Sequential, load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("/content/BRITANNIA.csv")

# %%
data.head()
# Out:
#          Date     Symbol Series  Prev Close   Open    High    Low   Last  \
# 0  2000-01-03  BRITANNIA     EQ      703.25  705.0  759.50  705.0  758.0
# 1  2000-01-04  BRITANNIA     EQ      756.90  710.0  770.00  710.0  740.0
# 2  2000-01-05  BRITANNIA     EQ      754.55  755.0  759.00  705.0  740.0
# 3  2000-01-06  BRITANNIA     EQ      735.30  740.0  794.15  740.0  770.0
# 4  2000-01-07  BRITANNIA     EQ      785.65  808.0  848.50  798.0  848.5
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  756.90  741.01    7512  5.566488e+11     NaN                 NaN
# 1  754.55  742.52    8135  6.040391e+11     NaN                 NaN
# 2  735.30  739.92    6095  4.509784e+11     NaN                 NaN
# 3  785.65  788.83   19697  1.553756e+12     NaN                 NaN
# 4  848.50  827.53   33107  2.739708e+12     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Preprocess the data
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)

# %%
# Dropping unnecessary columns
data.drop(['Symbol', 'Series', 'Trades', 'Deliverable Volume', '%Deliverble'], axis=1, inplace=True)

# Handling missing values
data.dropna(inplace=True)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Prepare the dataset for training
def prepare_data(data, n_steps):
    X, y = [], []
    for i in range(len(data)):
        end_ix = i + n_steps
        if end_ix > len(data) - 1:
            break
        seq_x, seq_y = data[i:end_ix, :], data[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

n_steps = 30
X, y = prepare_data(scaled_data, n_steps)

# %%
# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Build the RNN-GRU model
model = Sequential([
    GRU(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(9)  # Adjust the number of neurons to match the number of features in your labels
])


model.compile(optimizer='adam', loss='mse')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Make predictions
predictions = model.predict(X_test)
# Out:
# Epoch 1/100
# 132/132 [==============================] - 6s 16ms/step - loss: 0.0041
# Epoch 2/100
# 132/132 [==============================] - 2s 14ms/step - loss: 7.8565e-05
# Epoch 3/100
# 132/132 [==============================] - 2s 13ms/step - loss: 7.2499e-05
# Epoch 4/100
# 132/132 [==============================] - 2s 14ms/step - loss: 6.9639e-05
# Epoch 5/100
# 132/132 [==============================] - 2s 14ms/step - loss: 6.4975e-05
# Epoch 6/100
# 132/132 [==============================] - 2s 14ms/step - loss: 6.2840e-05
# Epoch 7/100
# 132/132 [==============================] - 3s 19ms/step - loss: 6.3216e-05
# Epoch 8/100
# 132/132 [==============================] - 2s 15ms/step - loss: 5.9870e-05
# Epoch 9/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.9409e-05
# Epoch 10/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.9408e-05
# Epoch 11/100
# 132/132 [==============================] - 2s 12ms/step - loss: 5.8743e-05
# Epoch 12/100
# 132/132 [==============================] - 2s 12ms/step - loss: 5.6985e-05
# Epoch 13/100
# 132/132 [==============================] - 2s 16ms/step - loss: 5.5528e-05
# Epoch 14/100
# 132/132 [==============================] - 2s 17ms/step - loss: 5.5561e-05
# Epoch 15/100
# 132/132 [==============================] - 2s 12ms/step - loss: 5.5666e-05
# Epoch 16/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.5467e-05
# Epoch 17/100
# 132/132 [==============================] - 2s 12ms/step - loss: 5.5265e-05
# Epoch 18/100
# 132/132 [==============================] - 2s 14ms/step - loss: 5.4151e-05
# Epoch 19/100
# 132/132 [==============================] - 2s 17ms/step - loss: 5.3426e-05
# Epoch 20/100
# 132/132 [==============================] - 3s 20ms/step - loss: 5.3902e-05
# Epoch 21/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.2817e-05
# Epoch 22/100
# 132/132 [==============================] - 2s 15ms/step - loss: 5.3506e-05
# Epoch 23/100
# 132/132 [==============================] - 2s 15ms/step - loss: 5.4050e-05
# Epoch 24/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.2879e-05
# Epoch 25/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.3155e-05
# Epoch 26/100
# 132/132 [==============================] - 2s 16ms/step - loss: 5.3536e-05
# Epoch 27/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.2592e-05
# Epoch 28/100
# 132/132 [==============================] - 3s 25ms/step - loss: 5.2451e-05
# Epoch 29/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.1093e-05
# Epoch 30/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0274e-05
# Epoch 31/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.9961e-05
# Epoch 32/100
# 132/132 [==============================] - 2s 16ms/step - loss: 4.9898e-05
# Epoch 33/100
# 132/132 [==============================] - 2s 17ms/step - loss: 4.9810e-05
# Epoch 34/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.1799e-05
# Epoch 35/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0727e-05
# Epoch 36/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0792e-05
# Epoch 37/100
# 132/132 [==============================] - 2s 14ms/step - loss: 4.9914e-05
# Epoch 38/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0973e-05
# Epoch 39/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.0860e-05
# Epoch 40/100
# 132/132 [==============================] - 2s 16ms/step - loss: 4.9879e-05
# Epoch 41/100
# 132/132 [==============================] - 2s 14ms/step - loss: 5.3342e-05
# Epoch 42/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0330e-05
# Epoch 43/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0836e-05
# Epoch 44/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.9524e-05
# Epoch 45/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0020e-05
# Epoch 46/100
# 132/132 [==============================] - 3s 21ms/step - loss: 5.1335e-05
# Epoch 47/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.9988e-05
# Epoch 48/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.8435e-05
# Epoch 49/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8162e-05
# Epoch 50/100
# 132/132 [==============================] - 2s 14ms/step - loss: 5.0474e-05
# Epoch 51/100
# 132/132 [==============================] - 2s 16ms/step - loss: 4.9201e-05
# Epoch 52/100
# 132/132 [==============================] - 3s 20ms/step - loss: 4.9898e-05
# Epoch 53/100
# 132/132 [==============================] - 3s 22ms/step - loss: 4.8399e-05
# Epoch 54/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8485e-05
# Epoch 55/100
# 132/132 [==============================] - 2s 14ms/step - loss: 4.9813e-05
# Epoch 56/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8488e-05
# Epoch 57/100
# 132/132 [==============================] - 2s 17ms/step - loss: 4.8514e-05
# Epoch 58/100
# 132/132 [==============================] - 3s 22ms/step - loss: 4.8948e-05
# Epoch 59/100
# 132/132 [==============================] - 3s 22ms/step - loss: 4.9773e-05
# Epoch 60/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8450e-05
# Epoch 61/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.9212e-05
# Epoch 62/100
# 132/132 [==============================] - 4s 31ms/step - loss: 4.9223e-05
# Epoch 63/100
# 132/132 [==============================] - 4s 31ms/step - loss: 4.9027e-05
# Epoch 64/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.8056e-05
# Epoch 65/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.8941e-05
# Epoch 66/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.8620e-05
# Epoch 67/100
# 132/132 [==============================] - 2s 17ms/step - loss: 4.8812e-05
# Epoch 68/100
# 132/132 [==============================] - 2s 17ms/step - loss: 4.7192e-05
# Epoch 69/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.9426e-05
# Epoch 70/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7803e-05
# Epoch 71/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7682e-05
# Epoch 72/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.6506e-05
# Epoch 73/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0489e-05
# Epoch 74/100
# 132/132 [==============================] - 3s 21ms/step - loss: 4.8193e-05
# Epoch 75/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.9213e-05
# Epoch 76/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7947e-05
# Epoch 77/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.6508e-05
# Epoch 78/100
# 132/132 [==============================] - 2s 13ms/step - loss: 5.0755e-05
# Epoch 79/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7213e-05
# Epoch 80/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8524e-05
# Epoch 81/100
# 132/132 [==============================] - 3s 21ms/step - loss: 4.8355e-05
# Epoch 82/100
# 132/132 [==============================] - 2s 14ms/step - loss: 4.8106e-05
# Epoch 83/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.6978e-05
# Epoch 84/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7504e-05
# Epoch 85/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7698e-05
# Epoch 86/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8260e-05
# Epoch 87/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8174e-05
# Epoch 88/100
# 132/132 [==============================] - 3s 23ms/step - loss: 4.7998e-05
# Epoch 89/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7829e-05
# Epoch 90/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8010e-05
# Epoch 91/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7202e-05
# Epoch 92/100
# 132/132 [==============================] - 2s 14ms/step - loss: 4.8375e-05
# Epoch 93/100
# 132/132 [==============================] - 2s 12ms/step - loss: 4.6196e-05
# Epoch 94/100
# 132/132 [==============================] - 2s 16ms/step - loss: 4.8687e-05
# Epoch 95/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.7233e-05
# Epoch 96/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7369e-05
# Epoch 97/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.7720e-05
# Epoch 98/100
# 132/132 [==============================] - 2s 13ms/step - loss: 4.8057e-05
# Epoch 99/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.6646e-05
# Epoch 100/100
# 132/132 [==============================] - 2s 15ms/step - loss: 4.7216e-05
# 33/33 [==============================] - 0s 5ms/step

# %%
# Evaluate the model
score = model.evaluate(X_test, y_test)
print('Score: {}'.format(score))

# Apply the built model on test data
y_pred = model.predict(X_test)
y_test_pred = scaler.inverse_transform(y_pred)  # Use inverse transform to undo the scaling
y_test_actual = scaler.inverse_transform(y_test)
# Out:
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0015
# Score: 0.0014507891610264778
# 33/33 [==============================] - 0s 6ms/step

# %%
import matplotlib.pyplot as plt

# %%
# Create test dates
test_Dates = data.index[4000:4690]

# Define the figure size
fig_size = (40, 6)  # Adjust width and height as needed

# Create a new figure with the specified size
plt.figure(figsize=fig_size)

# Plot actual and predicted data
plt.plot(test_Dates, y_test_actual[-690:], label='Actual')
plt.plot(test_Dates, y_test_pred[-690:], label='Predicted')

# Add legend
plt.legend()

# Show the plot
plt.show()
